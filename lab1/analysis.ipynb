# %% [markdown]
# Your Report should include
# - Brief introduction of random number generator and random walk (less than one page)
# - Present the parameter you used and outline your codes
# - Results and analysis. (Proper figures or tables should be included to show the results)
# - Conclusion
#
# Bonus
# 1. Perform a more complicated random walk to simulate some physical system
# and compare your results with the analytic results or experimental results.
# - Initial value/Boundary condition
# - Biased random walk
# - Random walk in lattice that includes hoping (may also include hopping beyond first
# nearest neighbour)
# - Or any other topics related to random walks.

# %% [markdown]
# ### Bonus plan: Make a Monte Carlo simulation that calculates the probability of a drunk person returning to its original place after a long time.

# %%
from lab1 import *

# %%
plot_linear()
# Out:
# Linear fitting of random walk
# RNG: LCG
# taking the mean date of 500 particles, each walking 5000 steps, sampling every 10 steps
# Results Logged
# standard error: [  1.45196924e-05]
# slope: 0.6405800074664026
# expected slope: 3
#
# Results Logged
# duration: 4.522296190261841
#
# Linear fitting of random walk
# RNG: npRNG
# taking the mean date of 500 particles, each walking 5000 steps, sampling every 10 steps
# standard error: [  8.70370948e-07]
# slope: 1.0182450036987285
# expected slope: 3
#
# Results Logged
# duration: 0.15485405921936035
# The seed is predetermined for function LCG, so the slope of LCG is the same everytime, but npRNG changes everytime you run
