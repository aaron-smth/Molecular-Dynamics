# %%
from lab1 import *

# %%
plot_linear()
# Out:
# Linear fitting of random walk
# RNG: LCG
# taking the mean date of 500 particles, each walking 5000 steps, sampling every 10 steps
# standard error: [  2.64448409e-05]
# slope: 3.4626387781646533
# expected slope: 3
#
# Results Logged
# duration: 4.040191888809204
#
# Linear fitting of random walk
# RNG: numpy RNG
# taking the mean date of 500 particles, each walking 5000 steps, sampling every 10 steps
# standard error: [  1.78459818e-06]
# slope: 3.033249205114957
# expected slope: 3
#
# Results Logged
# duration: 5.906233787536621
# The seed is predetermined for function LCG, so the slope of LCG is the same everytime, but npRNG changes everytime you run
